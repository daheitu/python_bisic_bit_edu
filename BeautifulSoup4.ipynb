# %%
#BeautifulSoup
from bs4 import BeautifulSoup
import requests
url = 'http://www.zuihaodaxue.com/Greater_China_Ranking2019_0.html'#"https://python123.io/ws/demo.html" 
r = requests.get(url)
r.status_code
r.encoding
demo = r.text
# print(demo)
soup = BeautifulSoup(demo, "html.parser")
# print(soup.prettify())
soup.title #查看soup对象的title
soup.contents #查看链接标签
for link in soup.find_all("a"):
    print(link.get("href"))
#     try:
#         print("the a label is %s" % i.a)
#     except:
#         continue
# soup.a.attrs["href"] #.attrs获取标签的属性，返回字典
# soup.a.string #获取标签的字符串
# soup.p.string
# type(soup.contents)
# print(type(soup.a.next_siblings))
# for i in soup.a.next_siblings:
#     print(i)
# Out:
# index.html
# http://www.shanghairanking.com
# #
# http://weibo.com/u/5359069294
# index.html
# rankings.html
# worldrankings.html
# yuanchuanfenxi.html
# yaowen.html
# search.html
# http://www.zuihaodaxue.com/conference/index.html
# contact.html
# index.html
# rankings.html
# Greater_China_Ranking2019_0.html
# Greater_China_Ranking2018_0.html
# Greater_China_Ranking2017_0.html
# Greater_China_Ranking2016_0.html
# Greater_China_Ranking2015_0.html
# Greater_China_Ranking2014_0.html
# Greater_China_Ranking2013_0.html
# Greater_China_Ranking2012_0.html
# Greater_China_Ranking2011_0.html
# #
# Greater_China_Ranking_Methodology_2019.html
# Greater_China_Ranking_Resources.html
# Greater_China_Ranking_article.html
# World-University-Rankings/Tsinghua-University.html
# World-University-Rankings/Peking-University.html
# World-University-Rankings/The-Chinese-University-of-Hong-Kong.html
# World-University-Rankings/Zhejiang-University.html
# ...
